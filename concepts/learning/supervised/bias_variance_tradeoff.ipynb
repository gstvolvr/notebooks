# %% [markdown]
# # Bias + Variance Tradeoff

# %% [markdown]
# There's also a relationship between `model complexity` and `bias`. As a model becomes more complex (e.g. a high degree polynomial), it tends to overfit the training data and increase the expected variance.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Resources:
# [SU19: Topics on High-Dimensional Data Analytics]()
