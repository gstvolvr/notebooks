# %% [markdown]
# # Central Limit Theorem
# When independent random variables are added, their properly normalized sum tends to a normal distribution.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
x = [np.random.exponential(size=100).mean() for _ in range(10000)]
sns.distplot(x);

# %% [markdown]
# ### Resources:
# *
